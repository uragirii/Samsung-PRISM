# %% [markdown]
# # Train the Model
#
# This notebook contains code to train the model for FBA Matting

# %%
import pytorch_ssim
import torch
from torch.autograd import Variable
from torch import optim
import torch.nn as nn
import os
import cv2
import numpy as np
import sys
from PIL import Image, ImageEnhance

# %%
# Dataset Paths
IMAGE = "./Image"
ALPHA = "./Alpha"
TRIMAP = "./Trimap"

print("Total Images :", len(os.listdir(IMAGE)))
# Out:
# Total Images : 41245

# %%
#Custom Imports
#RAdam Optimizer 
from radam import RAdam
# Dataset Loader
from dataloader import DataLoader

# %% [markdown]
# # Initialize Model

# %%
from demo import np_to_torch,scale_input
from networks.models import build_model
from networks.transforms import trimap_transform, groupnorm_normalise_image

# %%
class Args:
  encoder = 'resnet50_GN_WS'
  decoder = 'fba_decoder'
  weights = 'default'
args=Args()
model = build_model(args)
# Out:
# modifying input layer to accept 11 channels

# %% [markdown]
# # Training Process

# %%
optimizer = RAdam(model.parameters())
dataset = DataLoader(IMAGE, TRIMAP, ALPHA)
dataset_len = len(dataset)

# %%
# Initialize the losses here
mse_loss_criteria = nn.MSELoss()
sad_loss_criteria = nn.L1Loss()
margin_ranking_loss_criteria = nn.MarginRankingLoss(margin=1.0)

# %%
import pickle
import time

def check_epochs(file_names):
    """
    Returns only filenames that contains "epoch_" in them
    """
    if len(file_names) ==0:
        return []
    epoch_names = []
    for names in file_names:
        if "epoch_" in names:
            epoch_names.append(names)
    return epoch_names

def load_saved_data():
    last_saved_model = sorted(check_epochs(os.listdir("./logs/")))[-1]
    print("Loading saved data from {}".format(last_saved_model))
    modelFile = open("./logs/"+last_saved_model, 'rb')
    modelPickle = pickle.load(modelFile)
    modelFile.close()
    saved_model = modelPickle['model']
    saved_lowest = modelPickle['lowest']        
    saved_dataset = modelPickle['dataset']        
    saved_epoch = modelPickle['epoch']
    saved_loss = modelPickle['loss']
    return (saved_model, saved_lowest, saved_dataset, saved_epoch, saved_loss)


def save_data(model, lowest, dataset, epoch, loss):
    """
    Save the data
    """
    epoch_name = "epoch_{:09d}".format(epoch)
    model_name = "model_{:09d}".format(epoch)
    epoch_data = {}
    epoch_data['model'] = model
    epoch_data['lowest'] = lowest
    epoch_data['dataset'] = dataset
    epoch_data['epoch'] = epoch
    epoch_data['loss'] = loss
    
    dbfile = open('./logs/'+epoch_name, 'ab')
    pickle.dump(epoch_data, dbfile)
    dbfile.close()
    torch.save(model.state_dict(), "./Saved Models/"+model_name)
    print("Saved data for epoch : {}".format(epoch))

# %%
# import pickle
# # Redundant functions
# # No need
# def log(model, loss, epoch, dataset, lowest_loss, loss_list,save=False):
#     """
#     This functions saves the data regarding different epochs
#     Data is saved after 10 epochs, and for the lowest loss value
#     if save is True, this function is run after predicting output
#     loss_list = dict with values "mse", "sad", "mr"
#     """
# #     First check if epoch is 0
#     main= None
#     if epoch == 0 and not save:
#         # Restore or load from main file and then start
#         if os.path.exists("./logs/main"):
#             mainFile = open("./logs/main", 'rb')
#             mainPickle = pickle.load(mainFile)
#             loaded_dataset = mainPickle['dataset']
#             loaded_model = mainPickle['model']
#             loaded_lowest = mainPickle['lowest']
#             loaded_epoch = mainPickle['epoch']
#             loaded_loss_list = mainPickle['loss_list']
#             print("Successfully loaded Data")
#             mainFile.close()
#             return (loaded_model, loaded_dataset, loaded_lowest, loaded_epoch, loaded_loss_list)
#         else:
#             # First time running model
#             print("Running for first time")
#             return (model,dataset,lowest_loss, epoch, loss_list)
#     elif epoch == 0 and save:
#         # In this case it will save a main file 
#         mainData = {}
#         mainData['dataset'] = dataset
#         mainData['model'] = model
#         mainData['lowest'] = loss
#         mainData['epoch'] = epoch
#         mainData['loss_list'] = loss_list
#         dbfile = open('./logs/main', 'ab')
#         pickle.dump(mainData, dbfile)
#         dbfile.close() 
#         return None
#     elif epoch>0 and not save:
#         # If its not the first epoch, not need to do anything
#         return (model,dataset,lowest_loss, epoch)
#     elif epoch>0 and save:
#         # Save data according to epochs
#         mainFile = open("./logs/main", 'rb')
#         mainPickle = pickle.load(mainFile)
#         mainFile.close()
#         if loss < lowest_loss:
#             mainData['lowest'] = loss
#         if epoch%10 == 0:
#             # Each multiple of 10 will have it own data save
#             mainData['epoch'] = epoch
#             mainData['loss_list'] = loss_list
#             dbfile = open('./logs/main', 'ab')
#             pickle.dump(mainData, dbfile)
#             dbfile.close()
            
#             file_name = "epoch_{}".format(epoch)
#             epochData = {}
#             epochData['dataset'] = dataset
#             epochData['model'] = dataset
#             epochData['loss'] = dataset
#             epochData['loss_list'] = dataset
#             epochData['epoch'] = epoch
            
#             dbfile = open('./logs/'+file_name, 'ab')
#             pickle.dump(epochData, dbfile)
#             dbfile.close()
#             print("Data saved for epoch :", i)
#         return None

# %%
#Loss value is stored in this list
loss_values={}
loss_values['mse'] = []
loss_values['sad'] = []
loss_values['mr'] = []
loss_values['total'] = []
lowest = 99999999999999999999
i=0
for _ in range(dataset_len):
    start_time = time.time()
    epoch = i
    if i ==0 and len(check_epochs(os.listdir("./logs/"))) !=0:
        # Load the data
        model, lowest, dataset, i, loss_values = load_saved_data()
        epoch = i
        
    elif i==0:
        print("No saved data found")
    print("Dataset {} out of {}".format(i, dataset_len))
    try:
        sample = dataset[i]
    except ValueError:
        continue
    optimizer.zero_grad()
    image_np, trimap_np, output = sample['image'], sample['trimap'], sample['output']
    h, w = trimap_np.shape[:2]

    image_scale_np = scale_input(image_np, 1.0, cv2.INTER_LANCZOS4)
    trimap_scale_np = scale_input(trimap_np, 1.0, cv2.INTER_LANCZOS4)

    image_torch = np_to_torch(image_scale_np)
    trimap_torch = np_to_torch(trimap_scale_np)
    output = torch.from_numpy(output)[None, :, :, :].float().cuda()
    trimap_transformed_torch = np_to_torch(trimap_transform(trimap_scale_np))
    image_transformed_torch = groupnorm_normalise_image(image_torch.clone(), format='nchw')

    pred_output = model(image_torch, trimap_torch, image_transformed_torch, trimap_transformed_torch)
    tranposed_output = cv2.resize(pred_output[0].cpu().detach().numpy().transpose((1, 2, 0)), (w, h), cv2.INTER_LANCZOS4)
    # 0 --> Alpha
    # 1-4 --> Fg
    # 4:7 --> Bg

    #mse_loss 
    mse_loss = mse_loss_criteria(pred_output, output)

    #sad loss
    sad_loss = sad_loss_criteria(pred_output, output)

    

    #margin ranking loss
    target = torch.ones(1, 1).to(device='cuda')
    mr_loss = margin_ranking_loss_criteria.forward(pred_output,output, target)
    #overall loss
    loss = 0.01*mse_loss+sad_loss+mr_loss
    loss_values['mse'].append(0.01*mse_loss.item())
    loss_values['sad'].append(sad_loss.item())
    loss_values['mr'].append(mr_loss.item())
    loss_values['total'].append(loss.item())
    print("Total Loss :",loss.item())
    if loss.item()<lowest:
        print("Lowest Loss:{} at {}".format(loss, i))
        lowest = loss.item()
    if epoch%100 == 0:
        # Save the data for this epoch
         save_data(model, lowest, dataset, i, loss_values)
    end_time = time.time()
    print("Time Taken for epoch :", format(end_time-start_time))
    loss.backward()
    optimizer.step()
    print()
    i+=1
# Out:
# Loading saved data from epoch_000009100
# Dataset 9100 out of 41245
# Total Loss : 149.88914489746094
# Saved data for epoch : 9100
# Time Taken for epoch : 34.712388038635254
#
# Dataset 9101 out of 41245
# Total Loss : 138.00808715820312
# Time Taken for epoch : 3.670738697052002
#
# Dataset 9102 out of 41245
# Total Loss : 159.649169921875
# Time Taken for epoch : 1.7401096820831299
#
# Dataset 9103 out of 41245
# Total Loss : 35.949951171875
# Time Taken for epoch : 3.675778865814209
#
# Dataset 9104 out of 41245
# Total Loss : 238.75282287597656
# Time Taken for epoch : 11.228214025497437
#
# Dataset 9105 out of 41245
# Total Loss : 94.8265380859375
# Time Taken for epoch : 12.834595203399658
#
# Dataset 9106 out of 41245
# Total Loss : 108.29341888427734
# Time Taken for epoch : 1.8195834159851074
#
# Dataset 9107 out of 41245
# Total Loss : 51.69748306274414
# Time Taken for epoch : 13.966834545135498
#
# Dataset 9108 out of 41245
# Total Loss : 58.77845001220703
# Time Taken for epoch : 1.8374710083007812
#
# Dataset 9109 out of 41245
# Dataset 9109 out of 41245
# Total Loss : 222.32192993164062
# Time Taken for epoch : 8.286926984786987
#
# Dataset 9110 out of 41245
# Total Loss : 225.6846466064453
# Time Taken for epoch : 1.5904979705810547
#
# Dataset 9111 out of 41245
# Total Loss : 135.02066040039062
# Time Taken for epoch : 1.8179049491882324
#
# Dataset 9112 out of 41245
# Total Loss : 113.14878845214844
# Time Taken for epoch : 1.8422770500183105
#
# Dataset 9113 out of 41245
# Total Loss : 95.30824279785156
# Time Taken for epoch : 3.7135090827941895
#
# Dataset 9114 out of 41245
# Total Loss : 83.5552749633789
# Time Taken for epoch : 3.165649890899658
#
# Dataset 9115 out of 41245
# Total Loss : 120.06532287597656
# Time Taken for epoch : 8.892977237701416
#
# Dataset 9116 out of 41245
# Total Loss : 300.1833190917969
# Time Taken for epoch : 13.510165452957153
#
# Dataset 9117 out of 41245
# Total Loss : 236.1436767578125
# Time Taken for epoch : 1.818631649017334
#
# Dataset 9118 out of 41245
# Total Loss : 281.9615783691406
# Time Taken for epoch : 14.307738304138184
#
# Dataset 9119 out of 41245
# Total Loss : 113.90567016601562
# Time Taken for epoch : 12.889482021331787
#
# Dataset 9120 out of 41245
# Total Loss : 208.5322265625
# Time Taken for epoch : 3.4415035247802734
#
# Dataset 9121 out of 41245
# Total Loss : 205.9627685546875
# Time Taken for epoch : 12.645210027694702
#
# Dataset 9122 out of 41245
# Total Loss : 309.8314208984375
# Time Taken for epoch : 10.747215747833252
#
# Dataset 9123 out of 41245
# Total Loss : 490.6933288574219
# Time Taken for epoch : 1.3884611129760742
#
# Dataset 9124 out of 41245
# Total Loss : 161.88162231445312
# Time Taken for epoch : 13.529732942581177
#
# Dataset 9125 out of 41245
# Total Loss : 260.84124755859375
# Time Taken for epoch : 1.7368137836456299
#
# Dataset 9126 out of 41245
# Total Loss : 123.07211303710938
# Time Taken for epoch : 7.170862674713135
#
# Dataset 9127 out of 41245
# Total Loss : 73.78172302246094
# Time Taken for epoch : 14.866878271102905
#
# Dataset 9128 out of 41245
# Total Loss : 147.46319580078125
# Time Taken for epoch : 14.545567512512207
#
# Dataset 9129 out of 41245
# Total Loss : 193.11717224121094
# Time Taken for epoch : 9.672609090805054
#
# Dataset 9130 out of 41245
# Total Loss : 78.26065826416016
# Time Taken for epoch : 2.326223611831665
#
# Dataset 9131 out of 41245
# Total Loss : 250.8484344482422
# Time Taken for epoch : 1.8463249206542969
#
# Dataset 9132 out of 41245
# Total Loss : 132.79306030273438
# Time Taken for epoch : 3.703860282897949
#
# Dataset 9133 out of 41245
# Total Loss : 177.86260986328125
# Time Taken for epoch : 8.534476518630981
#
# Dataset 9134 out of 41245
# Total Loss : 45.35083770751953
# Time Taken for epoch : 3.804495096206665
#
# Dataset 9135 out of 41245
# Total Loss : 176.0644989013672
# Time Taken for epoch : 1.9412739276885986
#
# Dataset 9136 out of 41245
# Total Loss : 53.209999084472656
# Time Taken for epoch : 30.946531057357788
#
# Dataset 9137 out of 41245
# Total Loss : 119.63239288330078
# Time Taken for epoch : 1.841639757156372
#
# Dataset 9138 out of 41245
# Total Loss : 245.51486206054688
# Time Taken for epoch : 3.862807512283325
#
# Dataset 9139 out of 41245
# Total Loss : 143.892578125
# Time Taken for epoch : 1.809190273284912
#
# Dataset 9140 out of 41245
# Total Loss : 199.83880615234375
# Time Taken for epoch : 3.757357120513916
#
# Dataset 9141 out of 41245
# Total Loss : 94.00382995605469
# Time Taken for epoch : 9.455873489379883
#
# Dataset 9142 out of 41245
# Total Loss : 311.2944641113281
# Time Taken for epoch : 6.938371658325195
#
# Dataset 9143 out of 41245
# Total Loss : 189.08340454101562
# Time Taken for epoch : 1.8391695022583008
#
# Dataset 9144 out of 41245
# Total Loss : 50.503822326660156
# Time Taken for epoch : 12.324098110198975
#
# Dataset 9145 out of 41245
# Total Loss : 175.517822265625
# Time Taken for epoch : 1.8362610340118408
#
# Dataset 9146 out of 41245
# Total Loss : 258.4541015625
# Time Taken for epoch : 1.8919346332550049
#
# Dataset 9147 out of 41245
# Total Loss : 198.20120239257812
# Time Taken for epoch : 10.62803840637207
#
# Dataset 9148 out of 41245
# Total Loss : 41.351661682128906
# Time Taken for epoch : 3.8304686546325684
#
# Dataset 9149 out of 41245
# Total Loss : 55.37281036376953
# Time Taken for epoch : 3.850149154663086
#
# Dataset 9150 out of 41245
# Total Loss : 55.40617370605469
# Time Taken for epoch : 3.8932714462280273
#
# Dataset 9151 out of 41245
# Total Loss : 105.44134521484375
# Time Taken for epoch : 3.1856465339660645
#
# Dataset 9152 out of 41245
# Total Loss : 72.10942840576172
# Time Taken for epoch : 1.8539855480194092
#
# Dataset 9153 out of 41245
# Total Loss : 181.31948852539062
# Time Taken for epoch : 10.013903856277466
#
# Dataset 9154 out of 41245
# Total Loss : 261.45758056640625
# Time Taken for epoch : 12.692171573638916
#
# Dataset 9155 out of 41245
# Total Loss : 225.54510498046875
# Time Taken for epoch : 4.387260913848877
#
# Dataset 9156 out of 41245
# Total Loss : 62.285667419433594
# Time Taken for epoch : 1.913346529006958
#
# Dataset 9157 out of 41245
# Total Loss : 288.1282958984375
# Time Taken for epoch : 13.992200136184692
#
# Dataset 9158 out of 41245
# Total Loss : 133.57574462890625
# Time Taken for epoch : 14.256125688552856
#
# Dataset 9159 out of 41245
# Total Loss : 68.74555206298828
# Time Taken for epoch : 10.078312873840332
#
# Dataset 9160 out of 41245
# Total Loss : 148.74070739746094
# Time Taken for epoch : 14.462709188461304
#
# Dataset 9161 out of 41245
# Total Loss : 67.69747924804688
# Time Taken for epoch : 1.869258165359497
#
# Dataset 9162 out of 41245
# Total Loss : 181.16238403320312
# Time Taken for epoch : 6.9061949253082275
#
# Dataset 9163 out of 41245
# Total Loss : 95.73416137695312
# Time Taken for epoch : 1.9048006534576416
#
# Dataset 9164 out of 41245
# Total Loss : 50.20021438598633
# Time Taken for epoch : 13.467310905456543
#
# Dataset 9165 out of 41245
# Total Loss : 40.47255325317383
# Time Taken for epoch : 15.214434623718262
#
# Dataset 9166 out of 41245
# Total Loss : 233.3446044921875
# Time Taken for epoch : 11.529356718063354
#
# Dataset 9167 out of 41245
# Total Loss : 164.4664764404297
# Time Taken for epoch : 3.729201555252075
#
# Dataset 9168 out of 41245
# Total Loss : 87.55264282226562
# Time Taken for epoch : 1.8152191638946533
#
# Dataset 9169 out of 41245
# Total Loss : 245.9254913330078
# Time Taken for epoch : 13.387371301651001
#
# Dataset 9170 out of 41245
# Total Loss : 230.03890991210938
# Time Taken for epoch : 14.565223693847656
#
# Dataset 9171 out of 41245
# Total Loss : 426.1221923828125
# Time Taken for epoch : 10.056509733200073
#
# Dataset 9172 out of 41245
# Total Loss : 348.04803466796875
# Time Taken for epoch : 1.7768027782440186
#
# Dataset 9173 out of 41245
# Total Loss : 128.99354553222656
# Time Taken for epoch : 93.7016704082489
#
# Dataset 9174 out of 41245
# Total Loss : 141.71197509765625
# Time Taken for epoch : 1.939631462097168
#
# Dataset 9175 out of 41245
# Total Loss : 196.50534057617188
# Time Taken for epoch : 13.527418851852417
#
# Dataset 9176 out of 41245
# Total Loss : 117.26077270507812
# Time Taken for epoch : 8.01520562171936
#
# Dataset 9177 out of 41245
# Total Loss : 155.10939025878906
# Time Taken for epoch : 13.777063369750977
#
# Dataset 9178 out of 41245
# Total Loss : 151.887451171875
# Time Taken for epoch : 4.409380912780762
#
# Dataset 9179 out of 41245
# Total Loss : 343.9560546875
# Time Taken for epoch : 3.2261486053466797
#
# Dataset 9180 out of 41245
# Total Loss : 202.4234619140625
# Time Taken for epoch : 3.7349605560302734
#
# Dataset 9181 out of 41245
# Total Loss : 177.80471801757812
# Time Taken for epoch : 12.010427713394165
#
# Dataset 9182 out of 41245
# Total Loss : 9.220075607299805
# Time Taken for epoch : 3.7060279846191406
#
# Dataset 9183 out of 41245
# Total Loss : 163.38905334472656
# Time Taken for epoch : 1.814849853515625
#
# Dataset 9184 out of 41245
# Total Loss : 318.94671630859375
# Time Taken for epoch : 12.338056087493896
#
# Dataset 9185 out of 41245
# Total Loss : 203.66346740722656
# Time Taken for epoch : 3.7186384201049805
#
# Dataset 9186 out of 41245
# Total Loss : 41.23057556152344
# Time Taken for epoch : 10.012845993041992
#
# Dataset 9187 out of 41245
# Total Loss : 110.68707275390625
# Time Taken for epoch : 1.8628590106964111
#
# Dataset 9188 out of 41245
# Total Loss : 186.0201416015625
# Time Taken for epoch : 1.9044625759124756
#
# Dataset 9189 out of 41245
# Total Loss : 56.80535125732422
# Time Taken for epoch : 3.8434979915618896
#
# Dataset 9190 out of 41245
# Total Loss : 173.5286407470703
# Time Taken for epoch : 12.936884641647339
#
# Dataset 9191 out of 41245
# Total Loss : 445.07110595703125
# Time Taken for epoch : 1.4590940475463867
#
# Dataset 9192 out of 41245
# Total Loss : 151.80206298828125
# Time Taken for epoch : 9.535302877426147
#
# Dataset 9193 out of 41245
# Total Loss : 208.83758544921875
# Time Taken for epoch : 12.576266050338745
#
# Dataset 9194 out of 41245
# Total Loss : 98.6861801147461
# Time Taken for epoch : 1.857297420501709
#
# Dataset 9195 out of 41245
# Dataset 9195 out of 41245
# Total Loss : 306.1353759765625
# Time Taken for epoch : 1.800793170928955
#
# Dataset 9196 out of 41245
# Total Loss : 196.7889862060547
# Time Taken for epoch : 1.5610647201538086
#
# Dataset 9197 out of 41245
# Total Loss : 146.06768798828125
# Time Taken for epoch : 1.3804950714111328
#
# Dataset 9198 out of 41245
# Total Loss : 48.143592834472656
# Time Taken for epoch : 1.9839849472045898
#
# Dataset 9199 out of 41245
# Total Loss : 202.55300903320312
# Time Taken for epoch : 4.6813366413116455
#
# Dataset 9200 out of 41245
# Total Loss : 24.020368576049805
# Saved data for epoch : 9200
# Time Taken for epoch : 31.874438524246216
#
# Dataset 9201 out of 41245
# Total Loss : 102.23543548583984
# Time Taken for epoch : 10.314923763275146
#
# Dataset 9202 out of 41245
# Total Loss : 124.91111755371094
# Time Taken for epoch : 1.802483320236206
#
# Dataset 9203 out of 41245
# Total Loss : 139.6294403076172
# Time Taken for epoch : 4.317499160766602
#
# Dataset 9204 out of 41245
# Total Loss : 265.580322265625
# Time Taken for epoch : 1.842184066772461
#
# Dataset 9205 out of 41245
# Total Loss : 127.70988464355469
# Time Taken for epoch : 12.314212083816528
#
# Dataset 9206 out of 41245
# Total Loss : 360.525390625
# Time Taken for epoch : 2.3848650455474854
#
# Dataset 9207 out of 41245
# Total Loss : 139.47720336914062
# Time Taken for epoch : 13.245880365371704
#
# Dataset 9208 out of 41245
# Total Loss : 257.4811706542969
# Time Taken for epoch : 13.298203468322754
#
# Dataset 9331 out of 41245
# Total Loss : 250.40817260742188
# Time Taken for epoch : 14.219001770019531
#
# Dataset 9332 out of 41245
# Total Loss : 154.6815185546875
# Time Taken for epoch : 3.698275089263916
#
# Dataset 9333 out of 41245
# Total Loss : 174.6214599609375
# Time Taken for epoch : 14.287297487258911
#
# Dataset 9334 out of 41245
# Total Loss : 108.58482360839844
# Time Taken for epoch : 13.98274040222168
#
# Dataset 9335 out of 41245
# Total Loss : 193.6239013671875
# Time Taken for epoch : 9.739928007125854
#
# Dataset 9336 out of 41245
# Total Loss : 240.68197631835938
# Time Taken for epoch : 13.231893301010132
#
# Dataset 9337 out of 41245
# Total Loss : 52.679168701171875
# Time Taken for epoch : 1.9296092987060547
#
# Dataset 9338 out of 41245
# Total Loss : 309.00604248046875
# Time Taken for epoch : 5.690059423446655
#
# Dataset 9339 out of 41245
# Total Loss : 43.99038314819336
# Time Taken for epoch : 3.8605568408966064
#
# Dataset 9340 out of 41245
# Total Loss : 61.44489669799805
# Time Taken for epoch : 17.353950262069702
#
# Dataset 9341 out of 41245
# Total Loss : 189.41201782226562
# Time Taken for epoch : 1.8525545597076416
#
# Dataset 9342 out of 41245
# Total Loss : 15.176796913146973
# Time Taken for epoch : 11.0605309009552
#
# Dataset 9343 out of 41245
# Total Loss : 179.5920867919922
# Time Taken for epoch : 13.834545850753784
#
# Dataset 9344 out of 41245
# Total Loss : 454.549072265625
# Time Taken for epoch : 14.22826075553894
#
# Dataset 9345 out of 41245
# Total Loss : 87.82766723632812
# Time Taken for epoch : 3.1349172592163086
#
# Dataset 9346 out of 41245
# Total Loss : 91.8434066772461
# Time Taken for epoch : 1.8182554244995117
#
# Dataset 9347 out of 41245
# Total Loss : 185.42303466796875
# Time Taken for epoch : 10.162424564361572
#
# Dataset 9348 out of 41245
# Total Loss : 100.90727996826172
# Time Taken for epoch : 18.940051555633545
#
# Dataset 9349 out of 41245
# Total Loss : 155.52993774414062
# Time Taken for epoch : 10.355324745178223
#
# Dataset 9350 out of 41245
# Total Loss : 221.54208374023438
# Time Taken for epoch : 13.878299236297607
#
# Dataset 9351 out of 41245
# Total Loss : 198.2205810546875
# Time Taken for epoch : 1.8362090587615967
#
# Dataset 9352 out of 41245
# Total Loss : 41.413475036621094
# Time Taken for epoch : 3.815000534057617
#
# Dataset 9353 out of 41245
# Total Loss : 139.83547973632812
# Time Taken for epoch : 3.0747182369232178
#
# Dataset 9354 out of 41245
# Total Loss : 72.2979736328125
# Time Taken for epoch : 1.8897731304168701
#
# Dataset 9355 out of 41245
# Total Loss : 79.17669677734375
# Time Taken for epoch : 1.7754826545715332
#
# Dataset 9356 out of 41245
# Total Loss : 50.783897399902344
# Time Taken for epoch : 1.7613730430603027
#
# Dataset 9357 out of 41245
# Total Loss : 28.053089141845703
# Time Taken for epoch : 12.37506628036499
#
# Dataset 9358 out of 41245
# Total Loss : 141.76124572753906
# Time Taken for epoch : 1.799821376800537
#
# Dataset 9359 out of 41245
# Total Loss : 273.8648986816406
# Time Taken for epoch : 1.3248133659362793
#
# Dataset 9360 out of 41245
# Total Loss : 225.50291442871094
# Time Taken for epoch : 1.7788829803466797
#
# Dataset 9361 out of 41245
# Total Loss : 68.62178802490234
# Time Taken for epoch : 7.051770925521851
#
# Dataset 9362 out of 41245
# Total Loss : 111.72339630126953
# Time Taken for epoch : 1.810018539428711
#
# Dataset 9363 out of 41245
# Total Loss : 80.77729797363281
# Time Taken for epoch : 3.658942461013794
#
# Dataset 9364 out of 41245
# Total Loss : 122.3262939453125
# Time Taken for epoch : 3.2201309204101562
#
# Dataset 9365 out of 41245
# Total Loss : 121.81090545654297
# Time Taken for epoch : 6.967923402786255
#
# Dataset 9366 out of 41245
# Total Loss : 79.19755554199219
# Time Taken for epoch : 3.719740390777588
#
# Dataset 9367 out of 41245
# Total Loss : 275.4695739746094
# Time Taken for epoch : 15.72429370880127
#
# Dataset 9368 out of 41245
# Total Loss : 111.88471221923828
# Time Taken for epoch : 31.73445987701416
#
# Dataset 9369 out of 41245
# Total Loss : 95.29000091552734
# Time Taken for epoch : 1.795957326889038
#
# Dataset 9370 out of 41245
# Total Loss : 217.44747924804688
# Time Taken for epoch : 1.8130764961242676
#
# Dataset 9371 out of 41245
# Total Loss : 101.58834838867188
# Time Taken for epoch : 3.7058207988739014
#
# Dataset 9372 out of 41245
# Total Loss : 49.54981231689453
# Time Taken for epoch : 3.7652595043182373
#
# Dataset 9373 out of 41245
# Total Loss : 83.57179260253906
# Time Taken for epoch : 95.36785745620728
#
# Dataset 9374 out of 41245
# Total Loss : 101.33201599121094
# Time Taken for epoch : 16.60983633995056
#
# Dataset 9375 out of 41245
# Total Loss : 374.6221923828125
# Time Taken for epoch : 1.8294181823730469
#
# Dataset 9376 out of 41245
# Total Loss : 44.74880599975586
# Time Taken for epoch : 3.7197959423065186
#
# Dataset 9377 out of 41245
# Total Loss : 435.5900573730469
# Time Taken for epoch : 1.4726667404174805
#
# Dataset 9378 out of 41245
# Total Loss : 86.57505798339844
# Time Taken for epoch : 7.279122352600098
#
# Dataset 9379 out of 41245
# Total Loss : 98.4577865600586
# Time Taken for epoch : 7.130009174346924
#
# Dataset 9380 out of 41245
# Total Loss : 247.75189208984375
# Time Taken for epoch : 1.7876636981964111
#
# Dataset 9381 out of 41245
# Total Loss : 191.0298309326172
# Time Taken for epoch : 1.9536798000335693
#
# Dataset 9382 out of 41245
# Total Loss : 241.34317016601562
# Time Taken for epoch : 14.04981279373169
#
# Dataset 9383 out of 41245
# Total Loss : 307.9541931152344
# Time Taken for epoch : 31.329921007156372
#
# Dataset 9384 out of 41245
# Total Loss : 238.21475219726562
# Time Taken for epoch : 10.59214997291565
#
# Dataset 9385 out of 41245
# Total Loss : 179.1065673828125
# Time Taken for epoch : 4.381939649581909
#
# Dataset 9386 out of 41245
# Total Loss : 290.8170471191406
# Time Taken for epoch : 14.311032772064209
#
# Dataset 9387 out of 41245
# Total Loss : 43.89927673339844
# Time Taken for epoch : 243.88751912117004
#
# Dataset 9388 out of 41245
# Total Loss : 170.5557098388672
# Time Taken for epoch : 1.9332072734832764
#
# Dataset 9389 out of 41245
# Total Loss : 239.0549774169922
# Time Taken for epoch : 1.8839454650878906
#
# Dataset 9390 out of 41245
# Total Loss : 203.95384216308594
# Time Taken for epoch : 13.208817958831787
#
# Dataset 9391 out of 41245
# Total Loss : 342.1024169921875
# Time Taken for epoch : 13.997825860977173
#
# Dataset 9392 out of 41245
# Total Loss : 94.96449279785156
# Time Taken for epoch : 4.324942111968994
#
# Dataset 9393 out of 41245
# Total Loss : 298.9879150390625
# Time Taken for epoch : 1.5579352378845215
#
# Dataset 9394 out of 41245
# Total Loss : 121.13984680175781
# Time Taken for epoch : 14.673166275024414
#
# Dataset 9395 out of 41245
# Total Loss : 38.99919891357422
# Time Taken for epoch : 3.7262964248657227
#
# Dataset 9396 out of 41245
# Total Loss : 102.32552337646484
# Time Taken for epoch : 12.991664409637451
#
# Dataset 9397 out of 41245
# Total Loss : 239.86097717285156
# Time Taken for epoch : 1.8476080894470215
#
# Dataset 9398 out of 41245
# Total Loss : 157.05245971679688
# Time Taken for epoch : 1.7862536907196045
#
# Dataset 9399 out of 41245
# Total Loss : 177.63221740722656
# Time Taken for epoch : 13.689078092575073
#
# Dataset 9400 out of 41245
# Total Loss : 295.9024353027344
# Saved data for epoch : 9400
# Time Taken for epoch : 18.69470715522766
#
# Dataset 9401 out of 41245
# Total Loss : 97.19175720214844
# Time Taken for epoch : 9.82322382926941
#
# Dataset 9402 out of 41245
# Total Loss : 162.81149291992188
# Time Taken for epoch : 10.78636908531189
#
# Dataset 9403 out of 41245
# Total Loss : 59.25703430175781
# Time Taken for epoch : 7.019243001937866
#
# Dataset 9404 out of 41245
# Total Loss : 97.1711654663086
# Time Taken for epoch : 1.5130283832550049
#
# Dataset 9405 out of 41245
# Total Loss : 99.58168029785156
# Time Taken for epoch : 30.559612035751343
#
# Dataset 9406 out of 41245
# Total Loss : 36.38908767700195
# Time Taken for epoch : 15.23410701751709
#
# Dataset 9407 out of 41245
# Total Loss : 175.15908813476562
# Time Taken for epoch : 3.748335838317871
#
# Dataset 9408 out of 41245
# Total Loss : 181.5641632080078
# Time Taken for epoch : 1.5746243000030518
#
# Dataset 9409 out of 41245
# Total Loss : 114.04296112060547
# Time Taken for epoch : 3.7795090675354004
#
# Dataset 9410 out of 41245
# Total Loss : 124.51213836669922
# Time Taken for epoch : 12.775992393493652
#
# Dataset 9411 out of 41245
# Total Loss : 136.76693725585938
# Time Taken for epoch : 1.8349106311798096
#
# Dataset 9412 out of 41245
# Total Loss : 212.64588928222656
# Time Taken for epoch : 13.167487382888794
#
# Dataset 9413 out of 41245
# Total Loss : 293.00177001953125
# Time Taken for epoch : 41.99475598335266
#
# Dataset 9414 out of 41245
# Total Loss : 114.01943969726562
# Time Taken for epoch : 10.494663715362549
#
# Dataset 9415 out of 41245
# Total Loss : 28.398834228515625
# Time Taken for epoch : 3.759428024291992
#
# Dataset 9416 out of 41245
# Total Loss : 202.56436157226562
# Time Taken for epoch : 9.810252666473389
#
# Dataset 9417 out of 41245
# Total Loss : 158.07077026367188
# Time Taken for epoch : 3.8003482818603516
#
# Dataset 9418 out of 41245
# Total Loss : 238.583984375
# Time Taken for epoch : 9.119793176651001
#
# Dataset 9419 out of 41245
# Total Loss : 122.0360107421875
# Time Taken for epoch : 8.300962209701538
#
# Dataset 9420 out of 41245
# Total Loss : 279.7718200683594
# Time Taken for epoch : 1.7796094417572021
#
# Dataset 9421 out of 41245
# Total Loss : 36.31547546386719
# Time Taken for epoch : 7.037540435791016
#
# Dataset 9422 out of 41245
# Total Loss : 134.2637176513672
# Time Taken for epoch : 1.8779609203338623
#
# Dataset 9423 out of 41245
# Total Loss : 158.46148681640625
# Time Taken for epoch : 11.695884227752686
#
# Dataset 9424 out of 41245
# Total Loss : 75.70669555664062
# Time Taken for epoch : 11.044412612915039
#
# Dataset 9425 out of 41245
# Total Loss : 349.55474853515625
# Time Taken for epoch : 11.46804928779602
#
# Dataset 9426 out of 41245
# Total Loss : 225.30999755859375
# Time Taken for epoch : 1.8180429935455322
#
# Dataset 9427 out of 41245
# Total Loss : 200.23696899414062
# Time Taken for epoch : 10.552112579345703
#
# Dataset 9428 out of 41245
# Total Loss : 287.76214599609375
# Time Taken for epoch : 9.630493402481079
#
# Dataset 9429 out of 41245
# Total Loss : 262.9791259765625
# Time Taken for epoch : 12.585028171539307
#
# Dataset 9430 out of 41245
# Total Loss : 181.3483428955078
# Time Taken for epoch : 3.782622814178467
#
# Dataset 9431 out of 41245
# Total Loss : 78.4845199584961
# Time Taken for epoch : 3.800058364868164
#
# Dataset 9432 out of 41245
# Total Loss : 163.38429260253906
# Time Taken for epoch : 1.839512825012207
#
# Dataset 9433 out of 41245
# Total Loss : 279.0397644042969
# Time Taken for epoch : 14.345803499221802
#
# Dataset 9434 out of 41245
# Total Loss : 123.26939392089844
# Time Taken for epoch : 6.793488264083862
#
# Dataset 9435 out of 41245
# Total Loss : 190.32098388671875
# Time Taken for epoch : 16.75098419189453
#
# Dataset 9436 out of 41245
# Total Loss : 420.9394226074219
# Time Taken for epoch : 1.4112389087677002
#
# Dataset 9437 out of 41245
# Total Loss : 285.0218811035156
# Time Taken for epoch : 3.712146043777466
#
# Dataset 9438 out of 41245
# Total Loss : 118.81846618652344
# Time Taken for epoch : 13.561375856399536
#
# Dataset 9439 out of 41245
# Total Loss : 166.72592163085938
# Time Taken for epoch : 1.5788567066192627
#
# Dataset 9440 out of 41245
# Total Loss : 149.40509033203125
# Time Taken for epoch : 1.5557637214660645
#
# Dataset 9441 out of 41245
# Total Loss : 130.64749145507812
# Time Taken for epoch : 12.785044193267822
#
# Dataset 9442 out of 41245
# Total Loss : 93.88079833984375
# Time Taken for epoch : 7.219669818878174
#
# Dataset 9443 out of 41245
# Total Loss : 185.2617645263672
# Time Taken for epoch : 1.793835163116455
#
# Dataset 9444 out of 41245
# Total Loss : 156.9083709716797
# Time Taken for epoch : 1.9003043174743652
#
# Dataset 9445 out of 41245
# Total Loss : 134.76596069335938
# Time Taken for epoch : 1.8495335578918457
#
# Dataset 9446 out of 41245
# Total Loss : 291.85772705078125
# Time Taken for epoch : 1.84600830078125
#
# Dataset 9447 out of 41245
# Total Loss : 211.8656768798828
# Time Taken for epoch : 12.624052286148071
#
# Dataset 9448 out of 41245
# Total Loss : 40.35654067993164
# Time Taken for epoch : 8.487694263458252
#
# Dataset 9449 out of 41245
# Total Loss : 118.56297302246094
# Time Taken for epoch : 15.80509901046753
#
# Dataset 9450 out of 41245
# Total Loss : 411.3451843261719
# Time Taken for epoch : 14.606024742126465
#
# Dataset 9451 out of 41245
# Total Loss : 323.7161865234375
# Time Taken for epoch : 1.597346544265747
#
# Dataset 9452 out of 41245
# Total Loss : 152.7895965576172
# Time Taken for epoch : 13.82966947555542
#
# Dataset 9453 out of 41245
# Total Loss : 275.69305419921875
# Time Taken for epoch : 3.189277172088623
#
# Dataset 9454 out of 41245
# Total Loss : 220.12646484375
# Time Taken for epoch : 14.130864143371582
#
# Dataset 9455 out of 41245
# Total Loss : 382.25439453125
# Time Taken for epoch : 13.006637334823608
#
# Dataset 9456 out of 41245
# Total Loss : 199.40138244628906
# Time Taken for epoch : 13.402233839035034
#
# Dataset 9457 out of 41245
# Total Loss : 130.04498291015625
# Time Taken for epoch : 2.647357225418091
#
# Dataset 9458 out of 41245
# Total Loss : 147.2600860595703
# Time Taken for epoch : 8.366473197937012
#
# Dataset 9459 out of 41245
# Total Loss : 184.92953491210938
# Time Taken for epoch : 3.2027831077575684
#
# Dataset 9460 out of 41245
# Total Loss : 336.645263671875
# Time Taken for epoch : 81.9196207523346
#
# Dataset 9461 out of 41245
# Total Loss : 137.77978515625
# Time Taken for epoch : 12.9051673412323
#
# Dataset 9462 out of 41245
# Total Loss : 72.58142852783203
# Time Taken for epoch : 3.7398898601531982
#
# Dataset 9463 out of 41245
# Total Loss : 249.1895294189453
# Time Taken for epoch : 10.370719909667969
#
# Dataset 9464 out of 41245
# Total Loss : 312.3533630371094
# Time Taken for epoch : 1.3885037899017334
#
# Dataset 9465 out of 41245
# Total Loss : 161.29946899414062
# Time Taken for epoch : 10.237826824188232
#
# Dataset 9466 out of 41245
# Total Loss : 154.7151336669922
# Time Taken for epoch : 1.809385061264038
#
# Dataset 9467 out of 41245
# Total Loss : 271.541015625
# Time Taken for epoch : 13.120897769927979
#
# Dataset 9468 out of 41245
# Total Loss : 156.02639770507812
# Time Taken for epoch : 3.7941205501556396
#
# Dataset 9469 out of 41245
# Total Loss : 203.10784912109375
# Time Taken for epoch : 9.940115690231323
#
# Dataset 9470 out of 41245
# Total Loss : 120.37623596191406
# Time Taken for epoch : 9.447835445404053
#
# Dataset 9471 out of 41245
# Total Loss : 204.20651245117188
# Time Taken for epoch : 10.02871060371399
#
# Dataset 9472 out of 41245
# Total Loss : 111.48004913330078
# Time Taken for epoch : 1.8294565677642822
#
# Dataset 9473 out of 41245
# Total Loss : 280.9520263671875
# Time Taken for epoch : 13.425474405288696
#
# Dataset 9474 out of 41245
# Total Loss : 101.25574493408203
# Time Taken for epoch : 1.3652312755584717
#
# Dataset 9475 out of 41245
# Total Loss : 376.4983825683594
# Time Taken for epoch : 3.7923951148986816
#
# Dataset 9476 out of 41245
# Total Loss : 277.7060546875
# Time Taken for epoch : 3.082813024520874
#
# Dataset 9477 out of 41245
# Total Loss : 60.21514892578125
# Time Taken for epoch : 1.8354682922363281
#
# Dataset 9478 out of 41245
# Total Loss : 410.4989929199219
# Time Taken for epoch : 10.669759750366211
#
# Dataset 9479 out of 41245
# Total Loss : 75.94068145751953
# Time Taken for epoch : 1.844698429107666
#
# Dataset 9480 out of 41245
# Total Loss : 286.56744384765625
# Time Taken for epoch : 11.89895248413086
#
# Dataset 9481 out of 41245
# Total Loss : 66.38214874267578
# Time Taken for epoch : 18.024768590927124
#
# Dataset 9482 out of 41245
# Total Loss : 21.212955474853516
# Time Taken for epoch : 1.8735294342041016
#
# Dataset 9483 out of 41245
# Total Loss : 176.78225708007812
# Time Taken for epoch : 14.423352718353271
#
# Dataset 9484 out of 41245
# Total Loss : 134.06796264648438
# Time Taken for epoch : 17.01782464981079
#
# Dataset 9485 out of 41245
# Total Loss : 281.531005859375
# Time Taken for epoch : 13.729207992553711
#
# Dataset 9486 out of 41245
# Total Loss : 253.7447509765625
# Time Taken for epoch : 1.831322193145752
#
# Dataset 9487 out of 41245
# Total Loss : 208.14242553710938
# Time Taken for epoch : 1.8015737533569336
#
# Dataset 9488 out of 41245
# Total Loss : 404.9810485839844
# Time Taken for epoch : 13.052002668380737
#
# Dataset 9489 out of 41245
# Total Loss : 181.52523803710938
# Time Taken for epoch : 1.8017609119415283
#
# Dataset 9490 out of 41245
# Total Loss : 164.91458129882812
# Time Taken for epoch : 2.818249225616455
#
# Dataset 9491 out of 41245
# Total Loss : 139.6773681640625
# Time Taken for epoch : 15.032722234725952
#
# Dataset 9492 out of 41245
# Total Loss : 86.90864562988281
# Time Taken for epoch : 3.7319061756134033
#
# Dataset 9493 out of 41245
# Total Loss : 141.5432891845703
# Time Taken for epoch : 9.569195747375488
#
# Dataset 9494 out of 41245
# Total Loss : 206.76803588867188
# Time Taken for epoch : 9.809700727462769
#
# Dataset 9495 out of 41245
# Total Loss : 72.8941650390625
# Time Taken for epoch : 1.3331916332244873
#
# Dataset 9496 out of 41245
# Total Loss : 343.2951354980469
# Time Taken for epoch : 10.186612844467163
#
# Dataset 9497 out of 41245
# Total Loss : 118.46863555908203
# Time Taken for epoch : 17.565884590148926
#
# Dataset 9498 out of 41245
# Total Loss : 331.68218994140625
# Time Taken for epoch : 3.263747453689575
#
# Dataset 9499 out of 41245
# Total Loss : 181.29408264160156
# Time Taken for epoch : 7.363179683685303
#
# Dataset 9500 out of 41245
# Total Loss : 285.26513671875
# Saved data for epoch : 9500
# Time Taken for epoch : 20.05457830429077
#
# Dataset 9501 out of 41245
# Total Loss : 223.06690979003906
# Time Taken for epoch : 3.7969861030578613
#
# Dataset 9502 out of 41245
# Total Loss : 215.83311462402344
# Time Taken for epoch : 13.63674783706665
#
# Dataset 9503 out of 41245
# Total Loss : 73.14985656738281
# Time Taken for epoch : 1.8855490684509277
#
# Dataset 9504 out of 41245
# Total Loss : 222.01901245117188
# Time Taken for epoch : 15.143069982528687
#
# Dataset 9505 out of 41245
# Total Loss : 131.12591552734375
# Time Taken for epoch : 7.067142009735107
#
# Dataset 9506 out of 41245
# Total Loss : 34.584938049316406
# Time Taken for epoch : 12.976135969161987
#
# Dataset 9507 out of 41245
# Total Loss : 323.576416015625
# Time Taken for epoch : 1.5702619552612305
#
# Dataset 9508 out of 41245
# Total Loss : 218.34121704101562
# Time Taken for epoch : 4.28018856048584
#
# Dataset 9509 out of 41245
# Total Loss : 312.0772399902344
# Time Taken for epoch : 13.565500736236572
#
# Dataset 9510 out of 41245
# Total Loss : 39.289146423339844
# Time Taken for epoch : 1.9593255519866943
#
# Dataset 9511 out of 41245
# Total Loss : 211.17601013183594
# Time Taken for epoch : 3.4617843627929688
#
# Dataset 9512 out of 41245
# Total Loss : 117.16504669189453
# Time Taken for epoch : 19.266878366470337
#
# Dataset 9513 out of 41245
# Total Loss : 100.57522583007812
# Time Taken for epoch : 1.8655331134796143
#
# Dataset 9514 out of 41245
# Total Loss : 107.76931762695312
# Time Taken for epoch : 1.892817497253418
#
# Dataset 9515 out of 41245
# Dataset 9515 out of 41245
# Total Loss : 203.92913818359375
# Time Taken for epoch : 1.8968465328216553
#
# Dataset 9516 out of 41245
# Total Loss : 54.9306526184082
# Time Taken for epoch : 12.957534313201904
#
# Dataset 9517 out of 41245
# Total Loss : 230.6439971923828
# Time Taken for epoch : 3.532498598098755
#
# Dataset 9518 out of 41245
# Total Loss : 202.45069885253906
# Time Taken for epoch : 12.232162237167358
#
# Dataset 9519 out of 41245
# Total Loss : 242.43215942382812
# Time Taken for epoch : 11.304977416992188
#
# Dataset 9520 out of 41245
# Total Loss : 68.0489501953125
# Time Taken for epoch : 1.9255106449127197
#
# Dataset 9521 out of 41245
# Total Loss : 101.01698303222656
# Time Taken for epoch : 1.8266916275024414
#
# Dataset 9522 out of 41245
# Total Loss : 58.98271179199219
# Time Taken for epoch : 6.945460796356201
#
# Dataset 9523 out of 41245
# Total Loss : 32.32814025878906
# Time Taken for epoch : 2.385542869567871
#
# Dataset 9524 out of 41245
# Total Loss : 93.704345703125
# Time Taken for epoch : 14.051618099212646
#
# Dataset 9525 out of 41245
# Total Loss : 367.3935546875
# Time Taken for epoch : 14.914155960083008
#
# Dataset 9526 out of 41245
# Total Loss : 100.06147766113281
# Time Taken for epoch : 3.7765798568725586
#
# Dataset 9527 out of 41245
# Total Loss : 178.96070861816406
# Time Taken for epoch : 3.660327911376953
#
# Dataset 9528 out of 41245
# Total Loss : 154.49551391601562
# Time Taken for epoch : 3.118049383163452
#
# Dataset 9529 out of 41245
# Total Loss : 312.1529541015625
# Time Taken for epoch : 14.18045949935913
#
# Dataset 9530 out of 41245
# Total Loss : 166.7215118408203
# Time Taken for epoch : 7.325622081756592
#
# Dataset 9531 out of 41245
# Total Loss : 231.6012420654297
# Time Taken for epoch : 1.8984274864196777
#
# Dataset 9532 out of 41245
# Total Loss : 495.2157287597656
# Time Taken for epoch : 18.19951891899109
#
# Dataset 9533 out of 41245
# Total Loss : 75.66350555419922
# Time Taken for epoch : 15.795337915420532
#
# Dataset 9534 out of 41245
# Total Loss : 75.5167236328125
# Time Taken for epoch : 3.7480242252349854
#
# Dataset 9535 out of 41245
# Total Loss : 25.29691505432129
# Time Taken for epoch : 3.83941388130188
#
# Dataset 9536 out of 41245
# Total Loss : 324.6257019042969
# Time Taken for epoch : 14.522902965545654
#
# Dataset 9537 out of 41245
# Total Loss : 70.95907592773438
# Time Taken for epoch : 1.9262759685516357
#
# Dataset 9538 out of 41245
# Total Loss : 52.17098617553711
# Time Taken for epoch : 1.8928313255310059
#
# Dataset 9539 out of 41245
# Total Loss : 60.59300994873047
# Time Taken for epoch : 3.759211540222168
#
# Dataset 9540 out of 41245
# Total Loss : 274.53271484375
# Time Taken for epoch : 9.748247385025024
#
# Dataset 9541 out of 41245
# Total Loss : 200.01243591308594
# Time Taken for epoch : 1.8301429748535156
#
# Dataset 9542 out of 41245
# Total Loss : 139.44540405273438
# Time Taken for epoch : 1.9025194644927979
#
# Dataset 9543 out of 41245
# Total Loss : 69.51913452148438
# Time Taken for epoch : 14.898690462112427
#
# Dataset 9544 out of 41245
# Total Loss : 132.49600219726562
# Time Taken for epoch : 1.8296608924865723
#
# Dataset 9545 out of 41245
# Total Loss : 119.6470947265625
# Time Taken for epoch : 12.78381896018982
#
# Dataset 9546 out of 41245
# Total Loss : 99.23721313476562
# Time Taken for epoch : 12.691786289215088
#
# Dataset 9547 out of 41245
# Total Loss : 26.98087501525879
# Time Taken for epoch : 1.8923709392547607
#
# Dataset 9548 out of 41245
# Total Loss : 72.68901824951172
# Time Taken for epoch : 7.057053327560425
#
# Dataset 9549 out of 41245
# Total Loss : 154.033935546875
# Time Taken for epoch : 14.006022930145264
#
# Dataset 9550 out of 41245
# Total Loss : 211.70419311523438
# Time Taken for epoch : 12.885499477386475
#
# Dataset 9551 out of 41245
# Total Loss : 165.18841552734375
# Time Taken for epoch : 1.895063877105713
#
# Dataset 9552 out of 41245
# Total Loss : 57.0507926940918
# Time Taken for epoch : 12.98697018623352
#
# Dataset 9553 out of 41245
# Total Loss : 153.12339782714844
# Time Taken for epoch : 1.546382188796997
#
# Dataset 9554 out of 41245
